# %%
import pandas as pd 
import numpy as np

# %%
sales = pd.read_csv("fact_sales.csv")
sales.head(10)
# Out:
#   Invoice_ID  Order_Date Customer_ID Product_ID Salesperson_ID  Quantity  \
# 0  INV000001  2025-12-12     CUST050    PROD067           SP12       129
# 1  INV000002  2025-09-05     CUST035    PROD098           SP20        12
# 2  INV000003  2024-10-13     CUST047    PROD055           SP16       110
# 3  INV000004  2025-10-09     CUST003    PROD016           SP13        27
# 4  INV000005  2024-09-04     CUST108    PROD065           SP20        36
# 5  INV000006  2025-05-23     CUST142    PROD036           SP01       118
# 6  INV000007  2025-03-24     CUST075    PROD067           SP20        59
# 7  INV000008  2024-08-31     CUST012    PROD049           SP10        86
# 8  INV000009  2024-05-13     CUST067    PROD080           SP07        18
# 9  INV000010  2025-04-10     CUST020    PROD082           SP10        29
#
#    Unit_Price  Discount_Percent  Sales_Amount  Cost_Amount    Profit  \
# 0      182.45              0.00      23536.05     14227.41   9308.64
# ...

# %%
sales.tail()
# Out:
#      Invoice_ID  Order_Date Customer_ID Product_ID Salesperson_ID  Quantity  \
# 9995  INV009996  2024-05-17     CUST113    PROD049           SP14        50
# 9996  INV009997  2024-08-19     CUST114    PROD073           SP01        74
# 9997  INV009998  2025-01-10     CUST146    PROD007           SP03        75
# 9998  INV009999  2025-01-27     CUST102    PROD096           SP08        25
# 9999  INV010000  2024-02-28     CUST196    PROD023           SP09       104
#
#       Unit_Price  Discount_Percent  Sales_Amount  Cost_Amount   Profit  \
# 9995      215.14              0.00      10757.00      7431.00  3326.00
# 9996      220.00              0.05      15466.00     10885.40  4580.60
# 9997      210.04              0.00      15753.00     10106.25  5646.75
# 9998       62.46              0.00       1561.50       956.00   605.50
# 9999       67.67              0.00       7037.68      4409.60  2628.08
#
#        Payment_Mode  Delivery_Days  Return_Flag
# ...

# %%
sales.shape
# Out:
# (10000, 14)

# %%
sales.columns
# Out:
# Index(['Invoice_ID', 'Order_Date', 'Customer_ID', 'Product_ID',
#        'Salesperson_ID', 'Quantity', 'Unit_Price', 'Discount_Percent',
#        'Sales_Amount', 'Cost_Amount', 'Profit', 'Payment_Mode',
#        'Delivery_Days', 'Return_Flag'],
#       dtype='str')

# %%
sales.info
# Out:
# <bound method DataFrame.info of      Invoice_ID  Order_Date Customer_ID Product_ID Salesperson_ID  Quantity  \
# 0     INV000001  2025-12-12     CUST050    PROD067           SP12       129
# 1     INV000002  2025-09-05     CUST035    PROD098           SP20        12
# 2     INV000003  2024-10-13     CUST047    PROD055           SP16       110
# 3     INV000004  2025-10-09     CUST003    PROD016           SP13        27
# 4     INV000005  2024-09-04     CUST108    PROD065           SP20        36
# ...         ...         ...         ...        ...            ...       ...
# 9995  INV009996  2024-05-17     CUST113    PROD049           SP14        50
# 9996  INV009997  2024-08-19     CUST114    PROD073           SP01        74
# 9997  INV009998  2025-01-10     CUST146    PROD007           SP03        75
# 9998  INV009999  2025-01-27     CUST102    PROD096           SP08        25
# 9999  INV010000  2024-02-28     CUST196    PROD023           SP09       104
#
# ...

# %%
sales['Discount_Percent'] = sales['Discount_Percent'] * 100

# %%
sales.tail
# Out:
# <bound method NDFrame.tail of      Invoice_ID  Order_Date Customer_ID Product_ID Salesperson_ID  Quantity  \
# 0     INV000001  2025-12-12     CUST050    PROD067           SP12       129
# 1     INV000002  2025-09-05     CUST035    PROD098           SP20        12
# 2     INV000003  2024-10-13     CUST047    PROD055           SP16       110
# 3     INV000004  2025-10-09     CUST003    PROD016           SP13        27
# 4     INV000005  2024-09-04     CUST108    PROD065           SP20        36
# ...         ...         ...         ...        ...            ...       ...
# 9995  INV009996  2024-05-17     CUST113    PROD049           SP14        50
# 9996  INV009997  2024-08-19     CUST114    PROD073           SP01        74
# 9997  INV009998  2025-01-10     CUST146    PROD007           SP03        75
# 9998  INV009999  2025-01-27     CUST102    PROD096           SP08        25
# 9999  INV010000  2024-02-28     CUST196    PROD023           SP09       104
#
# ...

# %%
sales.isnull().sum
# Out:
# <bound method DataFrame.sum of       Invoice_ID  Order_Date  Customer_ID  Product_ID  Salesperson_ID  \
# 0          False       False        False       False           False
# 1          False       False        False       False           False
# 2          False       False        False       False           False
# 3          False       False        False       False           False
# 4          False       False        False       False           False
# ...          ...         ...          ...         ...             ...
# 9995       False       False        False       False           False
# 9996       False       False        False       False           False
# 9997       False       False        False       False           False
# 9998       False       False        False       False           False
# 9999       False       False        False       False           False
#
#       Quantity  Unit_Price  Discount_Percent  Sales_Amount  Cost_Amount  \
# ...

# %%
sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
sales['Order_Date'] = pd.to_datetime(sales['Order_Date'])

# %%
sales.head
# Out:
# <bound method NDFrame.head of      Invoice_ID Order_Date Customer_ID Product_ID Salesperson_ID  Quantity  \
# 0     INV000001 2025-12-12     CUST050    PROD067           SP12       129
# 1     INV000002 2025-09-05     CUST035    PROD098           SP20        12
# 2     INV000003 2024-10-13     CUST047    PROD055           SP16       110
# 3     INV000004 2025-10-09     CUST003    PROD016           SP13        27
# 4     INV000005 2024-09-04     CUST108    PROD065           SP20        36
# ...         ...        ...         ...        ...            ...       ...
# 9995  INV009996 2024-05-17     CUST113    PROD049           SP14        50
# 9996  INV009997 2024-08-19     CUST114    PROD073           SP01        74
# 9997  INV009998 2025-01-10     CUST146    PROD007           SP03        75
# 9998  INV009999 2025-01-27     CUST102    PROD096           SP08        25
# 9999  INV010000 2024-02-28     CUST196    PROD023           SP09       104
#
# ...

# %%
sales.describe()
# Out:
#                        Order_Date      Quantity    Unit_Price  \
# count                       10000  10000.000000  10000.000000
# mean   2024-12-29 16:09:07.200000     77.497900    114.426317
# min           2024-01-01 00:00:00      5.000000      7.430000
# 25%           2024-06-30 00:00:00     41.000000     57.470000
# 50%           2024-12-28 00:00:00     78.000000    107.110000
# 75%           2025-07-01 00:00:00    114.000000    166.570000
# max           2025-12-30 00:00:00    149.000000    262.930000
# std                           NaN     41.905973     65.737555
#
#        Discount_Percent  Sales_Amount   Cost_Amount        Profit  \
# count       10000.00000  10000.000000  10000.000000  10000.000000
# mean            3.50500   8540.792104   5883.497489   2657.294615
# min             0.00000     52.010000     40.110000     11.900000
# 25%             0.00000   2917.720000   2047.780000    722.505000
# 50%             0.00000   6483.765000   4588.680000   1758.260000
# ...

# %%
sales[sales["Profit"] < 0]
# Out:
# Empty DataFrame
# Columns: [Invoice_ID, Order_Date, Customer_ID, Product_ID, Salesperson_ID, Quantity, Unit_Price, Discount_Percent, Sales_Amount, Cost_Amount, Profit, Payment_Mode, Delivery_Days, Return_Flag]
# Index: []

# %%
sales[(sales["Discount_Percent"] <=0)|(sales["Discount_Percent"] >= 100)]
# Out:
#      Invoice_ID Order_Date Customer_ID Product_ID Salesperson_ID  Quantity  \
# 0     INV000001 2025-12-12     CUST050    PROD067           SP12       129
# 1     INV000002 2025-09-05     CUST035    PROD098           SP20        12
# 2     INV000003 2024-10-13     CUST047    PROD055           SP16       110
# 3     INV000004 2025-10-09     CUST003    PROD016           SP13        27
# 4     INV000005 2024-09-04     CUST108    PROD065           SP20        36
# ...         ...        ...         ...        ...            ...       ...
# 9991  INV009992 2024-10-05     CUST088    PROD015           SP20        93
# 9995  INV009996 2024-05-17     CUST113    PROD049           SP14        50
# 9997  INV009998 2025-01-10     CUST146    PROD007           SP03        75
# 9998  INV009999 2025-01-27     CUST102    PROD096           SP08        25
# 9999  INV010000 2024-02-28     CUST196    PROD023           SP09       104
#
# ...

# %%
sales["Profit_Margin"] = (sales["Profit"]/sales["Sales_Amount"]) * 100

# %%
sales.head()
# Out:
#   Invoice_ID Order_Date Customer_ID Product_ID Salesperson_ID  Quantity  \
# 0  INV000001 2025-12-12     CUST050    PROD067           SP12       129
# 1  INV000002 2025-09-05     CUST035    PROD098           SP20        12
# 2  INV000003 2024-10-13     CUST047    PROD055           SP16       110
# 3  INV000004 2025-10-09     CUST003    PROD016           SP13        27
# 4  INV000005 2024-09-04     CUST108    PROD065           SP20        36
#
#    Unit_Price  Discount_Percent  Sales_Amount  Cost_Amount   Profit  \
# 0      182.45               0.0      23536.05     14227.41  9308.64
# 1      113.41               0.0       1360.92      1123.92   237.00
# 2       39.60               0.0       4356.00      2888.60  1467.40
# 3       47.33               0.0       1277.91      1004.67   273.24
# 4       98.37               0.0       3541.32      2146.68  1394.64
#
#     Payment_Mode  Delivery_Days  Return_Flag  Profit_Margin
# 0    Credit Card              2            1      39.550562
# ...

# %%
sales["Year"] = sales["Order_Date"].dt.year

# %%
sales.head()
# Out:
#   Invoice_ID Order_Date Customer_ID Product_ID Salesperson_ID  Quantity  \
# 0  INV000001 2025-12-12     CUST050    PROD067           SP12       129
# 1  INV000002 2025-09-05     CUST035    PROD098           SP20        12
# 2  INV000003 2024-10-13     CUST047    PROD055           SP16       110
# 3  INV000004 2025-10-09     CUST003    PROD016           SP13        27
# 4  INV000005 2024-09-04     CUST108    PROD065           SP20        36
#
#    Unit_Price  Discount_Percent  Sales_Amount  Cost_Amount   Profit  \
# 0      182.45               0.0      23536.05     14227.41  9308.64
# 1      113.41               0.0       1360.92      1123.92   237.00
# 2       39.60               0.0       4356.00      2888.60  1467.40
# 3       47.33               0.0       1277.91      1004.67   273.24
# 4       98.37               0.0       3541.32      2146.68  1394.64
#
#     Payment_Mode  Delivery_Days  Return_Flag  Profit_Margin  Year
# ...

# %%
sales["Month"] = sales["Order_Date"].dt.month_name()

# %%
sales.head()
# Out:
#   Invoice_ID Order_Date Customer_ID Product_ID Salesperson_ID  Quantity  \
# 0  INV000001 2025-12-12     CUST050    PROD067           SP12       129
# 1  INV000002 2025-09-05     CUST035    PROD098           SP20        12
# 2  INV000003 2024-10-13     CUST047    PROD055           SP16       110
# 3  INV000004 2025-10-09     CUST003    PROD016           SP13        27
# 4  INV000005 2024-09-04     CUST108    PROD065           SP20        36
#
#    Unit_Price  Discount_Percent  Sales_Amount  Cost_Amount   Profit  \
# 0      182.45               0.0      23536.05     14227.41  9308.64
# 1      113.41               0.0       1360.92      1123.92   237.00
# 2       39.60               0.0       4356.00      2888.60  1467.40
# 3       47.33               0.0       1277.91      1004.67   273.24
# 4       98.37               0.0       3541.32      2146.68  1394.64
#
#     Payment_Mode  Delivery_Days  Return_Flag  Profit_Margin  Year      Month
# ...

# %%
sales["Quarter"] = sales["Order_Date"].dt.quarter

# %%
sales.head()
# Out:
#   Invoice_ID Order_Date Customer_ID Product_ID Salesperson_ID  Quantity  \
# 0  INV000001 2025-12-12     CUST050    PROD067           SP12       129
# 1  INV000002 2025-09-05     CUST035    PROD098           SP20        12
# 2  INV000003 2024-10-13     CUST047    PROD055           SP16       110
# 3  INV000004 2025-10-09     CUST003    PROD016           SP13        27
# 4  INV000005 2024-09-04     CUST108    PROD065           SP20        36
#
#    Unit_Price  Discount_Percent  Sales_Amount  Cost_Amount   Profit  \
# 0      182.45               0.0      23536.05     14227.41  9308.64
# 1      113.41               0.0       1360.92      1123.92   237.00
# 2       39.60               0.0       4356.00      2888.60  1467.40
# 3       47.33               0.0       1277.91      1004.67   273.24
# 4       98.37               0.0       3541.32      2146.68  1394.64
#
#     Payment_Mode  Delivery_Days  Return_Flag  Profit_Margin  Year      Month  \
# ...

# %%
sales["Payment_Mode"].unique()
# Out:
# <StringArray>
# ['Credit Card', 'Bank Transfer', 'Cheque', 'Cash']
# Length: 4, dtype: str

# %%
sales["Return_Flag"].value_counts()
# Out:
# Return_Flag
# 0    9680
# 1     320
# Name: count, dtype: int64

# %%
sales.to_csv("fact_sales_clean.csv",index=False)

# %%
inventory = pd.read_csv("fact_inventory.csv")

# %%
inventory.head()
# Out:
#   Product_ID Warehouse  Opening_Stock  Stock_Received  Quantity_Sold  \
# 0    PROD001  WH-North            280            9813           9269
# 1    PROD002  WH-South            101            8833           8619
# 2    PROD003   WH-West            437            7455           7251
# 3    PROD004  WH-South            281           10217           9645
# 4    PROD005   WH-East            289            8276           7630
#
#    Current_Stock  Reorder_Level  Safety_Stock Stock_Status Expiry_Month
# 0            824            452           180     In Stock      2027-12
# 1            315            482           192      Reorder      2027-12
# 2            641            350           140     In Stock      2027-12
# 3            853            262           104     In Stock      2027-12
# 4            935            405           162     In Stock      2027-06

# %%
inventory.info
# Out:
# <bound method DataFrame.info of    Product_ID Warehouse  Opening_Stock  Stock_Received  Quantity_Sold  \
# 0     PROD001  WH-North            280            9813           9269
# 1     PROD002  WH-South            101            8833           8619
# 2     PROD003   WH-West            437            7455           7251
# 3     PROD004  WH-South            281           10217           9645
# 4     PROD005   WH-East            289            8276           7630
# ..        ...       ...            ...             ...            ...
# 95    PROD096   WH-East            949            8365           7650
# 96    PROD097   WH-West            985            8464           7509
# 97    PROD098  WH-South            136            9641           9332
# 98    PROD099  WH-South            858            7698           7261
# 99    PROD100  WH-South            364            7948           7465
#
#     Current_Stock  Reorder_Level  Safety_Stock Stock_Status Expiry_Month
# ...

# %%
inventory.describe()
# Out:
#        Opening_Stock  Stock_Received  Quantity_Sold  Current_Stock  \
# count     100.000000       100.00000     100.000000     100.000000
# mean      507.360000      8277.08000    7749.790000    1034.650000
# std       305.975556       958.65835     907.981815     530.053845
# min        89.000000      6542.00000    5962.000000     134.000000
# 25%       278.750000      7673.25000    7101.750000     541.500000
# 50%       438.000000      8202.00000    7657.000000     980.500000
# 75%       704.250000      8845.75000    8255.250000    1418.250000
# max      1321.000000     10790.00000   10065.000000    1983.000000
#
#        Reorder_Level  Safety_Stock
# count     100.000000    100.000000
# mean      369.640000    147.440000
# std        89.862917     35.941681
# min       200.000000     80.000000
# 25%       292.250000    116.250000
# 50%       373.000000    149.000000
# 75%       446.000000    177.750000
# max       499.000000    199.000000

# %%
inventory[inventory["Current_Stock"] <= inventory["Reorder_Level"]]
# Out:
#    Product_ID Warehouse  Opening_Stock  Stock_Received  Quantity_Sold  \
# 1     PROD002  WH-South            101            8833           8619
# 8     PROD009  WH-South            127            7836           7609
# 16    PROD017  WH-South             89            7979           7861
# 47    PROD048  WH-South            118            8218           8090
# 48    PROD049   WH-West            116            6685           6555
# 66    PROD067   WH-West            158            7581           7504
# 68    PROD069  WH-South             92            8065           8023
# 74    PROD075   WH-East             91            6622           6487
# 77    PROD078   WH-East            268            7443           7308
# 79    PROD080  WH-South            161            7327           7237
#
#     Current_Stock  Reorder_Level  Safety_Stock Stock_Status Expiry_Month
# 1             315            482           192      Reorder      2027-12
# ...

# %%
inventory["Stock_Status"].value_counts()
# Out:
# Stock_Status
# In Stock    90
# Reorder     10
# Name: count, dtype: int64

# %%
inventory["Calculated_Stock"] = (
    inventory["Opening_Stock"] +
    inventory["Stock_Received"] -
    inventory["Quantity_Sold"]
)

# %%
inventory[["Current_Stock", "Calculated_Stock"]].head()
# Out:
#    Current_Stock  Calculated_Stock
# 0            824               824
# 1            315               315
# 2            641               641
# 3            853               853
# 4            935               935

# %%
inventory.to_csv("fact_inventory_clean.csv", index=False)

# %%
products = pd.read_csv("dim_products.csv")

# %%
products.shape
# Out:
# (100, 11)

# %%
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Product_ID         100 non-null    str
#  1   Medicine_Name      100 non-null    str
#  2   Generic_Name       100 non-null    str
#  3   Category           100 non-null    str
#  4   Manufacturer       100 non-null    str
#  5   Dosage_Form        100 non-null    str
#  6   Strength           100 non-null    str
#  7   Pack_Size          100 non-null    str
#  8   MRP                100 non-null    float64
#  9   Cost_Price         100 non-null    float64
#  10  Shelf_Life_Months  100 non-null    int64
# dtypes: float64(2), int64(1), str(8)
# memory usage: 5.5 KB

# %%
products["Medicine_Name"].duplicated().sum()
# Out:
# np.int64(3)

# %%
products["Category"].value_counts()
# Out:
# Category
# Antidiabetics       15
# Vitamins            14
# Cardiovascular      13
# Gastrointestinal    12
# Antibiotics         11
# Neurology            9
# Analgesics           9
# Dermatology          7
# Respiratory          6
# Anti-Allergy         4
# Name: count, dtype: int64

# %%
products["Manufacturer"].value_counts()
# Out:
# Manufacturer
# Johnson & Johnson       17
# Pfizer                  16
# Roche                   14
# GSK                     13
# AstraZeneca             11
# Sanofi                   8
# AbbVie                   6
# Merck                    6
# Bristol Myers Squibb     5
# Novartis                 4
# Name: count, dtype: int64

# %%
products["Shelf_Life_Months"].describe()
# Out:
# count    100.00000
# mean      22.56000
# std        8.86751
# min       12.00000
# 25%       18.00000
# 50%       18.00000
# 75%       36.00000
# max       36.00000
# Name: Shelf_Life_Months, dtype: float64

# %%
products.to_csv("dim_products_clean.csv", index=False)

# %%
salesperson = pd.read_csv("dim_salesperson.csv")

# %%
salesperson.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Salesperson_ID    20 non-null     str
#  1   Salesperson_Name  20 non-null     str
#  2   Territory         20 non-null     str
#  3   Experience_Years  20 non-null     int64
#  4   Target            20 non-null     int64
#  5   Manager           20 non-null     str
# dtypes: int64(2), str(4)
# memory usage: 712.0 bytes

# %%
salesperson.shape
# Out:
# (20, 6)

# %%
salesperson["Territory"].value_counts()
# Out:
# Territory
# Northeast    7
# West         6
# South        4
# Midwest      3
# Name: count, dtype: int64

# %%
salesperson["Target"].describe()
# Out:
# count        20.000000
# mean     180000.000000
# std       61558.701125
# min      100000.000000
# 25%      137500.000000
# 50%      175000.000000
# 75%      250000.000000
# max      250000.000000
# Name: Target, dtype: float64

# %%
salesperson["Manager"].value_counts()
# Out:
# Manager
# Bob Manager        5
# Charlie Manager    5
# Diana Manager      5
# Alice Manager      5
# Name: count, dtype: int64

# %%
salesperson.to_csv("dim_salesperson_clean.csv", index=False)

# %%
dates = pd.read_csv("dim_dates.csv")

# %%
dates.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        730 non-null    str
#  1   Day         730 non-null    int64
#  2   Month       730 non-null    int64
#  3   Month_Name  730 non-null    str
#  4   Quarter     730 non-null    int64
#  5   Year        730 non-null    int64
#  6   Weekday     730 non-null    str
#  7   Weekend     730 non-null    int64
# dtypes: int64(5), str(3)
# memory usage: 37.1 KB

# %%
dates.shape
# Out:
# (730, 8)

# %%
dates["Year"].value_counts()
# Out:
# Year
# 2024    366
# 2025    364
# Name: count, dtype: int64

# %%
dates.to_csv("dim_dates_clean.csv", index=False)
